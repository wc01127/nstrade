# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## 1. Imports and Setup

# %%
import sys
import os
import pandas as pd
import matplotlib.pyplot as plt

sys.path.append("../src")

from strategy import Strategy
from backtest import run_backtest

# %% [markdown]
# # 2. Load and clean data

# %%
# Load your BTC/USD hourly data
data_path = '../data/btc_hour.csv'
df = pd.read_csv(data_path)
df.head()
# Out:
#                         time   high    low   open  volumefrom  volumeto  \
# 0  2011-11-28 00:00:00+00:00  2.499  2.461  2.480     3457.45   8571.74
# 1  2011-11-28 01:00:00+00:00  2.498  2.480  2.497      681.46   1698.15
# 2  2011-11-28 02:00:00+00:00  2.499  2.485  2.498      624.29   1559.13
# 3  2011-11-28 03:00:00+00:00  2.498  2.442  2.487     2648.16   6519.05
# 4  2011-11-28 04:00:00+00:00  2.500  2.440  2.442     4299.98  10667.19
#
#    close conversionType conversionSymbol
# 0  2.497         direct              NaN
# 1  2.498         direct              NaN
# 2  2.487         direct              NaN
# 3  2.442         direct              NaN
# 4  2.462         direct              NaN

# %%
df
# Out:
#                              time        high         low        open  \
# 0       2011-11-28 00:00:00+00:00       2.499       2.461       2.480
# 1       2011-11-28 01:00:00+00:00       2.498       2.480       2.497
# 2       2011-11-28 02:00:00+00:00       2.499       2.485       2.498
# 3       2011-11-28 03:00:00+00:00       2.498       2.442       2.487
# 4       2011-11-28 04:00:00+00:00       2.500       2.440       2.442
# ...                           ...         ...         ...         ...
# 118054  2025-05-16 22:00:00+00:00  103649.830  103450.360  103643.590
# 118055  2025-05-16 23:00:00+00:00  103718.440  103465.470  103551.320
# 118056  2025-05-17 00:00:00+00:00  103569.600  103141.310  103499.600
# 118057  2025-05-17 01:00:00+00:00  103388.090  102642.390  103388.020
# 118058  2025-05-17 02:00:00+00:00  103316.880  102779.280  102859.210
#
#         volumefrom      volumeto       close conversionType conversionSymbol
# 0          3457.45  8.571740e+03       2.497         direct              NaN
# 1           681.46  1.698150e+03       2.498         direct              NaN
# 2           624.29  1.559130e+03       2.487         direct              NaN
# 3          2648.16  6.519050e+03       2.442         direct              NaN
# 4          4299.98  1.066719e+04       2.462         direct              NaN
# ...            ...           ...         ...            ...              ...
# 118054      978.41  1.012609e+08  103551.320         direct              NaN
# 118055      312.40  3.235507e+07  103499.600         direct              NaN
# 118056      488.11  5.044067e+07  103388.020         direct              NaN
# 118057      669.72  6.891526e+07  102859.210         direct              NaN
# 118058      263.48  2.715254e+07  103307.020         direct              NaN
#
# [118059 rows x 9 columns]

# %%
# Data cleaning: keep only time, close, volumeto; cast time to datetime; rename volumeto to volume
df = df[['time', 'close', 'volumeto']].copy()
df['time'] = pd.to_datetime(df['time'])
df = df.rename(columns={'volumeto': 'volume'})
df.head()
# Out:
#                        time  close    volume
# 0 2011-11-28 00:00:00+00:00  2.497   8571.74
# 1 2011-11-28 01:00:00+00:00  2.498   1698.15
# 2 2011-11-28 02:00:00+00:00  2.487   1559.13
# 3 2011-11-28 03:00:00+00:00  2.442   6519.05
# 4 2011-11-28 04:00:00+00:00  2.462  10667.19

# %%
df.tail()
# Out:
#                             time      close        volume
# 118054 2025-05-16 22:00:00+00:00  103551.32  1.012609e+08
# 118055 2025-05-16 23:00:00+00:00  103499.60  3.235507e+07
# 118056 2025-05-17 00:00:00+00:00  103388.02  5.044067e+07
# 118057 2025-05-17 01:00:00+00:00  102859.21  6.891526e+07
# 118058 2025-05-17 02:00:00+00:00  103307.02  2.715254e+07

# %% [markdown]
# # 3. Define strategy

# %% [markdown]
# ### Buy and Hold strategy

# %%
class BuyAndHoldStrategy(Strategy):
    def __init__(self, initial_capital=10000):
        super().__init__(initial_capital)
        self.has_bought = False

    def process_bar(self, bar):
        self.current_bar = bar

    def get_signal(self):
        if not self.has_bought:
            self.has_bought = True
            return 'buy'
        return 'hold'

# %% [markdown]
# ### SMA Crossover Strategy

# %%
class SMACrossoverStrategy(Strategy):
    def __init__(self, initial_capital=10000, fast=20, slow=100):
        super().__init__(initial_capital)
        self.prices = []
        self.fast = fast
        self.slow = slow
        self.last_signal = 'hold'

    def process_bar(self, bar):
        self.current_bar = bar
        self.prices.append(bar['close'])
        if len(self.prices) < self.slow:
            self.last_signal = 'hold'
            return

        fast_ma = pd.Series(self.prices).rolling(self.fast).mean().iloc[-1]
        slow_ma = pd.Series(self.prices).rolling(self.slow).mean().iloc[-1]

        if fast_ma > slow_ma and self.position == 0:
            self.last_signal = 'buy'
        elif fast_ma < slow_ma and self.position == 1:
            self.last_signal = 'sell'
        else:
            self.last_signal = 'hold'

    def get_signal(self):
        return self.last_signal

# %% [markdown]
# # 4. Run Backtests

# %%
bt_df = df.tail(20000).copy()

# Buy and Hold
bh_results = run_backtest(BuyAndHoldStrategy, bt_df, initial_capital=10000)

# SMA Crossover
sma_results = run_backtest(
    lambda initial_capital: SMACrossoverStrategy(initial_capital, fast=20, slow=100),
    bt_df,
    initial_capital=10000
)
# Out:
# BUY: time=2023-02-03 19:00:00+00:00, entry_idx=0, equity_curve_len=1, coins=0.4289246173563489
# FINAL SELL: time=2025-05-17 02:00:00+00:00, exit_idx=20000, equity_curve_len=20001, coins=0.4289246173563489
# REALIZED DD: entry_idx=0, exit_idx=20000, equity_len=20002
# BUY: time=2023-02-08 05:00:00+00:00, entry_idx=106, equity_curve_len=107, coins=0.4305167492541297
# SELL: time=2023-02-08 23:00:00+00:00, exit_idx=124, equity_curve_len=125, coins=0.4305167492541297
# BUY: time=2023-02-14 14:00:00+00:00, entry_idx=259, equity_curve_len=260, coins=0.44448481003910933
# SELL: time=2023-02-21 23:00:00+00:00, exit_idx=436, equity_curve_len=437, coins=0.44448481003910933
# BUY: time=2023-02-27 11:00:00+00:00, entry_idx=568, equity_curve_len=569, coins=0.4639161427357211
# SELL: time=2023-03-02 14:00:00+00:00, exit_idx=643, equity_curve_len=644, coins=0.4639161427357211
# BUY: time=2023-03-07 01:00:00+00:00, entry_idx=750, equity_curve_len=751, coins=0.4810045899305159
# SELL: time=2023-03-07 18:00:00+00:00, exit_idx=767, equity_curve_len=768, coins=0.4810045899305159
# BUY: time=2023-03-12 21:00:00+00:00, entry_idx=890, equity_curve_len=891, coins=0.497390318040618
# SELL: time=2023-03-23 04:00:00+00:00, exit_idx=1137, equity_curve_len=1138, coins=0.497390318040618
# BUY: time=2023-03-24 00:00:00+00:00, entry_idx=1157, equity_curve_len=1158, coins=0.48152262552566893
# SELL: time=2023-03-24 21:00:00+00:00, exit_idx=1178, equity_curve_len=1179, coins=0.48152262552566893
# BUY: time=2023-03-26 21:00:00+00:00, entry_idx=1226, equity_curve_len=1227, coins=0.4731988073572208
# SELL: time=2023-03-27 15:00:00+00:00, exit_idx=1244, equity_curve_len=1245, coins=0.4731988073572208
# BUY: time=2023-03-29 10:00:00+00:00, entry_idx=1287, equity_curve_len=1288, coins=0.4487914680844188
# SELL: time=2023-04-02 18:00:00+00:00, exit_idx=1391, equity_curve_len=1392, coins=0.4487914680844188
# BUY: time=2023-04-05 02:00:00+00:00, entry_idx=1447, equity_curve_len=1448, coins=0.4425903722937605
# SELL: time=2023-04-06 06:00:00+00:00, exit_idx=1475, equity_curve_len=1476, coins=0.4425903722937605
# BUY: time=2023-04-09 22:00:00+00:00, entry_idx=1563, equity_curve_len=1564, coins=0.43764285402059994
# SELL: time=2023-04-16 09:00:00+00:00, exit_idx=1718, equity_curve_len=1719, coins=0.43764285402059994
# BUY: time=2023-04-19 00:00:00+00:00, entry_idx=1781, equity_curve_len=1782, coins=0.4371851629409554
# SELL: time=2023-04-19 11:00:00+00:00, exit_idx=1792, equity_curve_len=1793, coins=0.4371851629409554
# BUY: time=2023-04-25 22:00:00+00:00, entry_idx=1947, equity_curve_len=1948, coins=0.4538674310095385
# SELL: time=2023-04-30 11:00:00+00:00, exit_idx=2056, equity_curve_len=2057, coins=0.4538674310095385
# BUY: time=2023-04-30 15:00:00+00:00, entry_idx=2060, equity_curve_len=2061, coins=0.446838615167353
# SELL: time=2023-05-01 04:00:00+00:00, exit_idx=2073, equity_curve_len=2074, coins=0.446838615167353
# BUY: time=2023-05-04 03:00:00+00:00, entry_idx=2144, equity_curve_len=2145, coins=0.43837508717091195
# SELL: time=2023-05-07 03:00:00+00:00, exit_idx=2216, equity_curve_len=2217, coins=0.43837508717091195
# BUY: time=2023-05-15 00:00:00+00:00, entry_idx=2405, equity_curve_len=2406, coins=0.4723837519918448
# SELL: time=2023-05-17 06:00:00+00:00, exit_idx=2459, equity_curve_len=2460, coins=0.4723837519918448
# BUY: time=2023-05-18 05:00:00+00:00, entry_idx=2482, equity_curve_len=2483, coins=0.4685045903398582
# SELL: time=2023-05-18 22:00:00+00:00, exit_idx=2499, equity_curve_len=2500, coins=0.4685045903398582
# BUY: time=2023-05-21 02:00:00+00:00, entry_idx=2551, equity_curve_len=2552, coins=0.46358337034722613
# SELL: time=2023-05-21 20:00:00+00:00, exit_idx=2569, equity_curve_len=2570, coins=0.46358337034722613
# BUY: time=2023-05-23 03:00:00+00:00, entry_idx=2600, equity_curve_len=2601, coins=0.45478211270892177
# SELL: time=2023-05-24 12:00:00+00:00, exit_idx=2633, equity_curve_len=2634, coins=0.45478211270892177
# BUY: time=2023-05-27 05:00:00+00:00, entry_idx=2698, equity_curve_len=2699, coins=0.45409761275018495
# SELL: time=2023-05-31 12:00:00+00:00, exit_idx=2801, equity_curve_len=2802, coins=0.45409761275018495
# BUY: time=2023-06-03 13:00:00+00:00, entry_idx=2874, equity_curve_len=2875, coins=0.4523678507323252
# SELL: time=2023-06-05 08:00:00+00:00, exit_idx=2917, equity_curve_len=2918, coins=0.4523678507323252
# BUY: time=2023-06-07 07:00:00+00:00, entry_idx=2964, equity_curve_len=2965, coins=0.45189592229040465
# SELL: time=2023-06-07 23:00:00+00:00, exit_idx=2980, equity_curve_len=2981, coins=0.45189592229040465
# BUY: time=2023-06-08 21:00:00+00:00, entry_idx=3002, equity_curve_len=3003, coins=0.44799371015270534
# SELL: time=2023-06-10 05:00:00+00:00, exit_idx=3034, equity_curve_len=3035, coins=0.44799371015270534
# BUY: time=2023-06-13 11:00:00+00:00, entry_idx=3112, equity_curve_len=3113, coins=0.43672864504456665
# SELL: time=2023-06-14 21:00:00+00:00, exit_idx=3146, equity_curve_len=3147, coins=0.43672864504456665
# BUY: time=2023-06-16 19:00:00+00:00, entry_idx=3192, equity_curve_len=3193, coins=0.41601232431946844
# SELL: time=2023-06-26 08:00:00+00:00, exit_idx=3421, equity_curve_len=3422, coins=0.41601232431946844
# BUY: time=2023-06-27 20:00:00+00:00, entry_idx=3457, equity_curve_len=3458, coins=0.4126236565968948
# SELL: time=2023-06-28 12:00:00+00:00, exit_idx=3473, equity_curve_len=3474, coins=0.4126236565968948
# BUY: time=2023-06-29 19:00:00+00:00, entry_idx=3504, equity_curve_len=3505, coins=0.4060594376607132
# SELL: time=2023-07-01 05:00:00+00:00, exit_idx=3538, equity_curve_len=3539, coins=0.4060594376607132
# BUY: time=2023-07-01 14:00:00+00:00, entry_idx=3547, equity_curve_len=3548, coins=0.40363258201803576
# SELL: time=2023-07-05 12:00:00+00:00, exit_idx=3641, equity_curve_len=3642, coins=0.40363258201803576
# BUY: time=2023-07-10 20:00:00+00:00, entry_idx=3769, equity_curve_len=3770, coins=0.39763644761116396
# SELL: time=2023-07-13 09:00:00+00:00, exit_idx=3830, equity_curve_len=3831, coins=0.39763644761116396
# BUY: time=2023-07-13 15:00:00+00:00, entry_idx=3836, equity_curve_len=3837, coins=0.3931471523472378
# SELL: time=2023-07-15 04:00:00+00:00, exit_idx=3873, equity_curve_len=3874, coins=0.3931471523472378
# BUY: time=2023-07-23 18:00:00+00:00, entry_idx=4079, equity_curve_len=4080, coins=0.3939189278127903
# SELL: time=2023-07-24 09:00:00+00:00, exit_idx=4094, equity_curve_len=4095, coins=0.3939189278127903
# BUY: time=2023-07-27 11:00:00+00:00, entry_idx=4168, equity_curve_len=4169, coins=0.38946668023815
# SELL: time=2023-07-28 05:00:00+00:00, exit_idx=4186, equity_curve_len=4187, coins=0.38946668023815
# BUY: time=2023-07-28 18:00:00+00:00, entry_idx=4199, equity_curve_len=4200, coins=0.3877110640571816
# SELL: time=2023-07-30 19:00:00+00:00, exit_idx=4248, equity_curve_len=4249, coins=0.3877110640571816
# BUY: time=2023-07-31 02:00:00+00:00, entry_idx=4255, equity_curve_len=4256, coins=0.38426476980642393
# SELL: time=2023-08-01 00:00:00+00:00, exit_idx=4277, equity_curve_len=4278, coins=0.38426476980642393
# BUY: time=2023-08-02 06:00:00+00:00, entry_idx=4307, equity_curve_len=4308, coins=0.38074829726928433
# SELL: time=2023-08-03 03:00:00+00:00, exit_idx=4328, equity_curve_len=4329, coins=0.38074829726928433
# BUY: time=2023-08-08 04:00:00+00:00, entry_idx=4449, equity_curve_len=4450, coins=0.3803046059756352
# SELL: time=2023-08-11 07:00:00+00:00, exit_idx=4524, equity_curve_len=4525, coins=0.3803046059756352
# BUY: time=2023-08-14 20:00:00+00:00, entry_idx=4609, equity_curve_len=4610, coins=0.38046441077703147
# SELL: time=2023-08-15 11:00:00+00:00, exit_idx=4624, equity_curve_len=4625, coins=0.38046441077703147
# BUY: time=2023-08-23 18:00:00+00:00, entry_idx=4823, equity_curve_len=4824, coins=0.4217276839920837
# SELL: time=2023-08-25 06:00:00+00:00, exit_idx=4859, equity_curve_len=4860, coins=0.4217276839920837
# BUY: time=2023-08-29 02:00:00+00:00, entry_idx=4951, equity_curve_len=4952, coins=0.42051302139756275
# SELL: time=2023-08-29 13:00:00+00:00, exit_idx=4962, equity_curve_len=4963, coins=0.42051302139756275
# BUY: time=2023-08-29 14:00:00+00:00, entry_idx=4963, equity_curve_len=4964, coins=0.3979212376301639
# SELL: time=2023-09-01 01:00:00+00:00, exit_idx=5022, equity_curve_len=5023, coins=0.3979212376301639
# BUY: time=2023-09-04 18:00:00+00:00, entry_idx=5111, equity_curve_len=5112, coins=0.3990471879841864
# SELL: time=2023-09-04 22:00:00+00:00, exit_idx=5115, equity_curve_len=5116, coins=0.3990471879841864
# BUY: time=2023-09-07 21:00:00+00:00, entry_idx=5186, equity_curve_len=5187, coins=0.39297493036225817
# SELL: time=2023-09-10 09:00:00+00:00, exit_idx=5246, equity_curve_len=5247, coins=0.39297493036225817
# BUY: time=2023-09-12 17:00:00+00:00, entry_idx=5302, equity_curve_len=5303, coins=0.39167835930255035
# SELL: time=2023-09-21 14:00:00+00:00, exit_idx=5515, equity_curve_len=5516, coins=0.39167835930255035
# BUY: time=2023-09-28 00:00:00+00:00, entry_idx=5669, equity_curve_len=5670, coins=0.3939409995910461
# SELL: time=2023-10-04 04:00:00+00:00, exit_idx=5817, equity_curve_len=5818, coins=0.3939409995910461
# BUY: time=2023-10-04 23:00:00+00:00, entry_idx=5836, equity_curve_len=5837, coins=0.3882817603789346
# SELL: time=2023-10-05 21:00:00+00:00, exit_idx=5858, equity_curve_len=5859, coins=0.3882817603789346
# BUY: time=2023-10-06 17:00:00+00:00, entry_idx=5878, equity_curve_len=5879, coins=0.3810546369162064
# SELL: time=2023-10-09 13:00:00+00:00, exit_idx=5946, equity_curve_len=5947, coins=0.3810546369162064
# BUY: time=2023-10-15 02:00:00+00:00, entry_idx=6079, equity_curve_len=6080, coins=0.39009684772405373
# SELL: time=2023-10-27 19:00:00+00:00, exit_idx=6384, equity_curve_len=6385, coins=0.39009684772405373
# BUY: time=2023-10-29 17:00:00+00:00, entry_idx=6430, equity_curve_len=6431, coins=0.380264505182813
# SELL: time=2023-11-03 10:00:00+00:00, exit_idx=6543, equity_curve_len=6544, coins=0.380264505182813
# BUY: time=2023-11-04 16:00:00+00:00, entry_idx=6573, equity_curve_len=6574, coins=0.3753877113121613
# SELL: time=2023-11-07 15:00:00+00:00, exit_idx=6644, equity_curve_len=6645, coins=0.3753877113121613
# BUY: time=2023-11-07 20:00:00+00:00, entry_idx=6649, equity_curve_len=6650, coins=0.36570202604469854
# SELL: time=2023-11-13 16:00:00+00:00, exit_idx=6789, equity_curve_len=6790, coins=0.36570202604469854
# BUY: time=2023-11-16 01:00:00+00:00, entry_idx=6846, equity_curve_len=6847, coins=0.3600487192306476
# SELL: time=2023-11-17 04:00:00+00:00, exit_idx=6873, equity_curve_len=6874, coins=0.3600487192306476
# BUY: time=2023-11-18 12:00:00+00:00, entry_idx=6905, equity_curve_len=6906, coins=0.35984225206524845
# SELL: time=2023-11-18 13:00:00+00:00, exit_idx=6906, equity_curve_len=6907, coins=0.35984225206524845
# BUY: time=2023-11-18 14:00:00+00:00, entry_idx=6907, equity_curve_len=6908, coins=0.3590742520338029
# SELL: time=2023-11-19 10:00:00+00:00, exit_idx=6927, equity_curve_len=6928, coins=0.3590742520338029
# BUY: time=2023-11-19 22:00:00+00:00, entry_idx=6939, equity_curve_len=6940, coins=0.3548515550036099
# SELL: time=2023-11-22 02:00:00+00:00, exit_idx=6991, equity_curve_len=6992, coins=0.3548515550036099
# BUY: time=2023-11-23 03:00:00+00:00, entry_idx=7016, equity_curve_len=7017, coins=0.3451870168834708
# SELL: time=2023-11-26 23:00:00+00:00, exit_idx=7108, equity_curve_len=7109, coins=0.3451870168834708
# BUY: time=2023-11-28 23:00:00+00:00, entry_idx=7156, equity_curve_len=7157, coins=0.3417529029865599
# SELL: time=2023-12-11 02:00:00+00:00, exit_idx=7447, equity_curve_len=7448, coins=0.3417529029865599
# BUY: time=2023-12-14 05:00:00+00:00, entry_idx=7522, equity_curve_len=7523, coins=0.33495112746014416
# SELL: time=2023-12-16 07:00:00+00:00, exit_idx=7572, equity_curve_len=7573, coins=0.33495112746014416
# BUY: time=2023-12-16 13:00:00+00:00, entry_idx=7578, equity_curve_len=7579, coins=0.3335430932088298
# SELL: time=2023-12-17 02:00:00+00:00, exit_idx=7591, equity_curve_len=7592, coins=0.3335430932088298
# BUY: time=2023-12-19 06:00:00+00:00, entry_idx=7643, equity_curve_len=7644, coins=0.32531078244464223
# SELL: time=2023-12-24 14:00:00+00:00, exit_idx=7771, equity_curve_len=7772, coins=0.32531078244464223
# BUY: time=2023-12-28 03:00:00+00:00, entry_idx=7856, equity_curve_len=7857, coins=0.3276512738411844
# SELL: time=2023-12-28 19:00:00+00:00, exit_idx=7872, equity_curve_len=7873, coins=0.3276512738411844
# BUY: time=2024-01-01 01:00:00+00:00, entry_idx=7950, equity_curve_len=7951, coins=0.32781094686425527
# SELL: time=2024-01-04 00:00:00+00:00, exit_idx=8021, equity_curve_len=8022, coins=0.32781094686425527
# BUY: time=2024-01-06 23:00:00+00:00, entry_idx=8092, equity_curve_len=8093, coins=0.3197079187007876
# SELL: time=2024-01-12 11:00:00+00:00, exit_idx=8224, equity_curve_len=8225, coins=0.3197079187007876
# BUY: time=2024-01-16 18:00:00+00:00, entry_idx=8327, equity_curve_len=8328, coins=0.3415368269262204
# SELL: time=2024-01-17 17:00:00+00:00, exit_idx=8350, equity_curve_len=8351, coins=0.3415368269262204
# BUY: time=2024-01-26 08:00:00+00:00, entry_idx=8557, equity_curve_len=8558, coins=0.3604520573012031
# SELL: time=2024-02-01 04:00:00+00:00, exit_idx=8697, equity_curve_len=8698, coins=0.3604520573012031
# BUY: time=2024-02-02 07:00:00+00:00, entry_idx=8724, equity_curve_len=8725, coins=0.35173554487127745
# SELL: time=2024-02-04 23:00:00+00:00, exit_idx=8788, equity_curve_len=8789, coins=0.35173554487127745
# BUY: time=2024-02-06 20:00:00+00:00, entry_idx=8833, equity_curve_len=8834, coins=0.3475175177248659
# SELL: time=2024-02-17 23:00:00+00:00, exit_idx=9100, equity_curve_len=9101, coins=0.3475175177248659
# BUY: time=2024-02-19 02:00:00+00:00, entry_idx=9127, equity_curve_len=9128, coins=0.344256036182785
# SELL: time=2024-02-20 09:00:00+00:00, exit_idx=9158, equity_curve_len=9159, coins=0.344256036182785
# BUY: time=2024-02-20 12:00:00+00:00, entry_idx=9161, equity_curve_len=9162, coins=0.3414852052605902
# SELL: time=2024-02-20 18:00:00+00:00, exit_idx=9167, equity_curve_len=9168, coins=0.3414852052605902
# BUY: time=2024-02-20 19:00:00+00:00, entry_idx=9168, equity_curve_len=9169, coins=0.33760840182407925
# SELL: time=2024-02-21 10:00:00+00:00, exit_idx=9183, equity_curve_len=9184, coins=0.33760840182407925
# BUY: time=2024-02-25 03:00:00+00:00, entry_idx=9272, equity_curve_len=9273, coins=0.33536960908500485
# SELL: time=2024-03-15 01:00:00+00:00, exit_idx=9726, equity_curve_len=9727, coins=0.33536960908500485
# BUY: time=2024-03-21 06:00:00+00:00, entry_idx=9875, equity_curve_len=9876, coins=0.35828013728940045
# SELL: time=2024-03-22 14:00:00+00:00, exit_idx=9907, equity_curve_len=9908, coins=0.35828013728940045
# BUY: time=2024-03-24 23:00:00+00:00, entry_idx=9964, equity_curve_len=9965, coins=0.3343579867928668
# SELL: time=2024-03-29 18:00:00+00:00, exit_idx=10079, equity_curve_len=10080, coins=0.3343579867928668
# BUY: time=2024-03-30 18:00:00+00:00, entry_idx=10103, equity_curve_len=10104, coins=0.3320977594139992
# SELL: time=2024-03-30 21:00:00+00:00, exit_idx=10106, equity_curve_len=10107, coins=0.3320977594139992
# BUY: time=2024-03-31 06:00:00+00:00, entry_idx=10115, equity_curve_len=10116, coins=0.3298078702183155
# BUY: time=2025-04-01 11:00:00+00:00, entry_idx=18904, equity_curve_len=18905, coins=0.3538328419552935
# SELL: time=2025-04-03 14:00:00+00:00, exit_idx=18955, equity_curve_len=18956, coins=0.3538328419552935
# BUY: time=2025-04-10 01:00:00+00:00, entry_idx=19110, equity_curve_len=19111, coins=0.35069993449308057
# SELL: time=2025-04-16 04:00:00+00:00, exit_idx=19257, equity_curve_len=19258, coins=0.35069993449308057
# BUY: time=2025-04-17 19:00:00+00:00, entry_idx=19296, equity_curve_len=19297, coins=0.345410634511355
# SELL: time=2025-04-20 19:00:00+00:00, exit_idx=19368, equity_curve_len=19369, coins=0.345410634511355
# BUY: time=2025-04-21 01:00:00+00:00, entry_idx=19374, equity_curve_len=19375, coins=0.33495381237188865
# SELL: time=2025-04-28 04:00:00+00:00, exit_idx=19545, equity_curve_len=19546, coins=0.33495381237188865
# BUY: time=2025-04-28 06:00:00+00:00, entry_idx=19547, equity_curve_len=19548, coins=0.33300345003205567
# SELL: time=2025-04-30 23:00:00+00:00, exit_idx=19612, equity_curve_len=19613, coins=0.33300345003205567
# BUY: time=2025-05-01 09:00:00+00:00, entry_idx=19622, equity_curve_len=19623, coins=0.32824638335167816
# SELL: time=2025-05-04 11:00:00+00:00, exit_idx=19696, equity_curve_len=19697, coins=0.32824638335167816
# BUY: time=2025-05-07 05:00:00+00:00, entry_idx=19762, equity_curve_len=19763, coins=0.32521005555869925
# SELL: time=2025-05-12 22:00:00+00:00, exit_idx=19899, equity_curve_len=19900, coins=0.32521005555869925
# BUY: time=2025-05-13 23:00:00+00:00, entry_idx=19924, equity_curve_len=19925, coins=0.3212168424734446
# SELL: time=2025-05-14 19:00:00+00:00, exit_idx=19944, equity_curve_len=19945, coins=0.3212168424734446
# BUY: time=2025-05-16 06:00:00+00:00, entry_idx=19979, equity_curve_len=19980, coins=0.3190542791489665
# FINAL SELL: time=2025-05-17 02:00:00+00:00, exit_idx=20000, equity_curve_len=20001, coins=0.3190542791489665
# REALIZED DD: entry_idx=106, exit_idx=124, equity_len=20002
# REALIZED DD: entry_idx=259, exit_idx=436, equity_len=20002
# REALIZED DD: entry_idx=568, exit_idx=643, equity_len=20002
# REALIZED DD: entry_idx=750, exit_idx=767, equity_len=20002
# REALIZED DD: entry_idx=890, exit_idx=1137, equity_len=20002
# REALIZED DD: entry_idx=1157, exit_idx=1178, equity_len=20002
# REALIZED DD: entry_idx=1226, exit_idx=1244, equity_len=20002
# REALIZED DD: entry_idx=1287, exit_idx=1391, equity_len=20002
# REALIZED DD: entry_idx=1447, exit_idx=1475, equity_len=20002
# REALIZED DD: entry_idx=1563, exit_idx=1718, equity_len=20002
# REALIZED DD: entry_idx=1781, exit_idx=1792, equity_len=20002
# REALIZED DD: entry_idx=1947, exit_idx=2056, equity_len=20002
# REALIZED DD: entry_idx=2060, exit_idx=2073, equity_len=20002
# REALIZED DD: entry_idx=2144, exit_idx=2216, equity_len=20002
# REALIZED DD: entry_idx=2405, exit_idx=2459, equity_len=20002
# REALIZED DD: entry_idx=2482, exit_idx=2499, equity_len=20002
# REALIZED DD: entry_idx=2551, exit_idx=2569, equity_len=20002
# REALIZED DD: entry_idx=2600, exit_idx=2633, equity_len=20002
# REALIZED DD: entry_idx=2698, exit_idx=2801, equity_len=20002
# REALIZED DD: entry_idx=2874, exit_idx=2917, equity_len=20002
# REALIZED DD: entry_idx=2964, exit_idx=2980, equity_len=20002
# REALIZED DD: entry_idx=3002, exit_idx=3034, equity_len=20002
# REALIZED DD: entry_idx=3112, exit_idx=3146, equity_len=20002
# REALIZED DD: entry_idx=3192, exit_idx=3421, equity_len=20002
# REALIZED DD: entry_idx=3457, exit_idx=3473, equity_len=20002
# REALIZED DD: entry_idx=3504, exit_idx=3538, equity_len=20002
# REALIZED DD: entry_idx=3547, exit_idx=3641, equity_len=20002
# REALIZED DD: entry_idx=3769, exit_idx=3830, equity_len=20002
# REALIZED DD: entry_idx=3836, exit_idx=3873, equity_len=20002
# REALIZED DD: entry_idx=4079, exit_idx=4094, equity_len=20002
# REALIZED DD: entry_idx=4168, exit_idx=4186, equity_len=20002
# REALIZED DD: entry_idx=4199, exit_idx=4248, equity_len=20002
# REALIZED DD: entry_idx=4255, exit_idx=4277, equity_len=20002
# REALIZED DD: entry_idx=4307, exit_idx=4328, equity_len=20002
# REALIZED DD: entry_idx=4449, exit_idx=4524, equity_len=20002
# REALIZED DD: entry_idx=4609, exit_idx=4624, equity_len=20002
# REALIZED DD: entry_idx=4823, exit_idx=4859, equity_len=20002
# REALIZED DD: entry_idx=4951, exit_idx=4962, equity_len=20002
# REALIZED DD: entry_idx=4963, exit_idx=5022, equity_len=20002
# REALIZED DD: entry_idx=5111, exit_idx=5115, equity_len=20002
# REALIZED DD: entry_idx=5186, exit_idx=5246, equity_len=20002
# REALIZED DD: entry_idx=5302, exit_idx=5515, equity_len=20002
# REALIZED DD: entry_idx=5669, exit_idx=5817, equity_len=20002
# REALIZED DD: entry_idx=5836, exit_idx=5858, equity_len=20002
# REALIZED DD: entry_idx=5878, exit_idx=5946, equity_len=20002
# REALIZED DD: entry_idx=6079, exit_idx=6384, equity_len=20002
# REALIZED DD: entry_idx=6430, exit_idx=6543, equity_len=20002
# REALIZED DD: entry_idx=6573, exit_idx=6644, equity_len=20002
# REALIZED DD: entry_idx=6649, exit_idx=6789, equity_len=20002
# REALIZED DD: entry_idx=6846, exit_idx=6873, equity_len=20002
# REALIZED DD: entry_idx=6905, exit_idx=6906, equity_len=20002
# REALIZED DD: entry_idx=6907, exit_idx=6927, equity_len=20002
# REALIZED DD: entry_idx=6939, exit_idx=6991, equity_len=20002
# REALIZED DD: entry_idx=7016, exit_idx=7108, equity_len=20002
# REALIZED DD: entry_idx=7156, exit_idx=7447, equity_len=20002
# REALIZED DD: entry_idx=7522, exit_idx=7572, equity_len=20002
# REALIZED DD: entry_idx=7578, exit_idx=7591, equity_len=20002
# REALIZED DD: entry_idx=7643, exit_idx=7771, equity_len=20002
# REALIZED DD: entry_idx=7856, exit_idx=7872, equity_len=20002
# REALIZED DD: entry_idx=7950, exit_idx=8021, equity_len=20002
# REALIZED DD: entry_idx=8092, exit_idx=8224, equity_len=20002
# REALIZED DD: entry_idx=8327, exit_idx=8350, equity_len=20002
# REALIZED DD: entry_idx=8557, exit_idx=8697, equity_len=20002
# REALIZED DD: entry_idx=8724, exit_idx=8788, equity_len=20002
# REALIZED DD: entry_idx=8833, exit_idx=9100, equity_len=20002
# REALIZED DD: entry_idx=9127, exit_idx=9158, equity_len=20002
# REALIZED DD: entry_idx=9161, exit_idx=9167, equity_len=20002
# REALIZED DD: entry_idx=9168, exit_idx=9183, equity_len=20002
# REALIZED DD: entry_idx=9272, exit_idx=9726, equity_len=20002
# REALIZED DD: entry_idx=9875, exit_idx=9907, equity_len=20002
# REALIZED DD: entry_idx=9964, exit_idx=10079, equity_len=20002
# REALIZED DD: entry_idx=10103, exit_idx=10106, equity_len=20002
# REALIZED DD: entry_idx=10115, exit_idx=10147, equity_len=20002
# REALIZED DD: entry_idx=10230, exit_idx=10351, equity_len=20002
# REALIZED DD: entry_idx=10382, exit_idx=10415, equity_len=20002
# REALIZED DD: entry_idx=10573, exit_idx=10706, equity_len=20002
# REALIZED DD: entry_idx=10918, exit_idx=11017, equity_len=20002
# REALIZED DD: entry_idx=11080, exit_idx=11086, equity_len=20002
# REALIZED DD: entry_idx=11150, exit_idx=11399, equity_len=20002
# REALIZED DD: entry_idx=11448, exit_idx=11513, equity_len=20002
# REALIZED DD: entry_idx=11575, exit_idx=11588, equity_len=20002
# REALIZED DD: entry_idx=11648, exit_idx=11765, equity_len=20002
# REALIZED DD: entry_idx=12246, exit_idx=12265, equity_len=20002
# REALIZED DD: entry_idx=12308, exit_idx=12370, equity_len=20002
# REALIZED DD: entry_idx=12469, exit_idx=12484, equity_len=20002
# REALIZED DD: entry_idx=12511, exit_idx=12589, equity_len=20002
# REALIZED DD: entry_idx=12609, exit_idx=12752, equity_len=20002
# REALIZED DD: entry_idx=12766, exit_idx=12861, equity_len=20002
# REALIZED DD: entry_idx=12928, exit_idx=13016, equity_len=20002
# REALIZED DD: entry_idx=13238, exit_idx=13327, equity_len=20002
# REALIZED DD: entry_idx=13375, exit_idx=13398, equity_len=20002
# REALIZED DD: entry_idx=13457, exit_idx=13503, equity_len=20002
# REALIZED DD: entry_idx=13521, exit_idx=13548, equity_len=20002
# REALIZED DD: entry_idx=13559, exit_idx=13688, equity_len=20002
# REALIZED DD: entry_idx=13856, exit_idx=13874, equity_len=20002
# REALIZED DD: entry_idx=14010, exit_idx=14175, equity_len=20002
# REALIZED DD: entry_idx=14211, exit_idx=14409, equity_len=20002
# REALIZED DD: entry_idx=14416, exit_idx=14507, equity_len=20002
# REALIZED DD: entry_idx=14620, exit_idx=14711, equity_len=20002
# REALIZED DD: entry_idx=14787, exit_idx=15025, equity_len=20002
# REALIZED DD: entry_idx=15098, exit_idx=15130, equity_len=20002
# REALIZED DD: entry_idx=15166, exit_idx=15271, equity_len=20002
# REALIZED DD: entry_idx=15384, exit_idx=15620, equity_len=20002
# REALIZED DD: entry_idx=15624, exit_idx=15838, equity_len=20002
# REALIZED DD: entry_idx=15921, exit_idx=16027, equity_len=20002
# REALIZED DD: entry_idx=16081, exit_idx=16178, equity_len=20002
# REALIZED DD: entry_idx=16249, exit_idx=16416, equity_len=20002
# REALIZED DD: entry_idx=16564, exit_idx=16611, equity_len=20002
# REALIZED DD: entry_idx=16734, exit_idx=16742, equity_len=20002
# REALIZED DD: entry_idx=16756, exit_idx=16902, equity_len=20002
# REALIZED DD: entry_idx=16999, exit_idx=17032, equity_len=20002
# REALIZED DD: entry_idx=17055, exit_idx=17219, equity_len=20002
# REALIZED DD: entry_idx=17236, exit_idx=17262, equity_len=20002
# REALIZED DD: entry_idx=17293, exit_idx=17359, equity_len=20002
# REALIZED DD: entry_idx=17427, exit_idx=17481, equity_len=20002
# REALIZED DD: entry_idx=17559, exit_idx=17567, equity_len=20002
# REALIZED DD: entry_idx=17708, exit_idx=17743, equity_len=20002
# REALIZED DD: entry_idx=17770, exit_idx=17780, equity_len=20002
# REALIZED DD: entry_idx=17804, exit_idx=17860, equity_len=20002
# REALIZED DD: entry_idx=17935, exit_idx=17989, equity_len=20002
# REALIZED DD: entry_idx=18169, exit_idx=18229, equity_len=20002
# REALIZED DD: entry_idx=18257, exit_idx=18319, equity_len=20002
# REALIZED DD: entry_idx=18434, exit_idx=18463, equity_len=20002
# REALIZED DD: entry_idx=18474, exit_idx=18534, equity_len=20002
# REALIZED DD: entry_idx=18551, exit_idx=18560, equity_len=20002
# REALIZED DD: entry_idx=18598, exit_idx=18671, equity_len=20002
# REALIZED DD: entry_idx=18697, exit_idx=18795, equity_len=20002
# REALIZED DD: entry_idx=18904, exit_idx=18955, equity_len=20002
# REALIZED DD: entry_idx=19110, exit_idx=19257, equity_len=20002
# REALIZED DD: entry_idx=19296, exit_idx=19368, equity_len=20002
# REALIZED DD: entry_idx=19374, exit_idx=19545, equity_len=20002
# REALIZED DD: entry_idx=19547, exit_idx=19612, equity_len=20002
# REALIZED DD: entry_idx=19622, exit_idx=19696, equity_len=20002
# REALIZED DD: entry_idx=19762, exit_idx=19899, equity_len=20002
# REALIZED DD: entry_idx=19924, exit_idx=19944, equity_len=20002
# REALIZED DD: entry_idx=19979, exit_idx=20000, equity_len=20002

# %% [markdown]
# # 5. Compare Results

# %%
def print_metrics(name, results):
    print(f"--- {name} ---")
    print(f"Sharpe Ratio: {results['sharpe']:.2f}")
    print(f"Total Return: {results['total_return']*100:.2f}%")
    print(f"Annualized Return: {results['annualized_return']*100:.2f}%")
    print(f"Max Drawdown: {results['max_drawdown']*100:.2f}%")
    print(f"Number of Trades: {results['n_trades']}")
    print(f"Win Rate: {results['win_rate']*100:.2f}%")
    print()

print_metrics("Buy & Hold", bh_results)
print_metrics("SMA Crossover", sma_results)
# Out:
# --- Buy & Hold ---
# Sharpe Ratio: 1.58
# Total Return: 343.11%
# Annualized Return: 91.94%
# Max Drawdown: 32.28%
# Number of Trades: 1
# Win Rate: 0.00%
#
# --- SMA Crossover ---
# Sharpe Ratio: 1.65
# Total Return: 229.61%
# Annualized Return: 68.60%
# Max Drawdown: 29.11%
# Number of Trades: 136
# Win Rate: 45.59%

# %%
import matplotlib.dates as mdates

def plot_strategy_results(df, results, name="Strategy"):
    # Align index for plotting
    times = pd.to_datetime(df['time'])
    equity = results['equity_curve'].reset_index(drop=True)
    rolling_sharpe = results['rolling_sharpe'].reset_index(drop=True)
    unrealized_dd = results['unrealized_drawdown'].reset_index(drop=True)
    realized_dd = results['realized_drawdown'].reset_index(drop=True)

    fig, axs = plt.subplots(5, 1, figsize=(14, 18), sharex=True, gridspec_kw={'height_ratios': [2, 1, 2, 1, 1]})

    # 1. Price and Volume
    axs[0].plot(times, df['close'], label='BTC Price', color='blue')
    ax2 = axs[0].twinx()
    ax2.fill_between(times, df['volume'], color='gray', alpha=0.2, label='Volume')
    axs[0].set_ylabel('BTC Price')
    ax2.set_ylabel('Volume')
    axs[0].set_title(f"{name} - BTC Price and Volume")
    axs[0].legend(loc='upper left')
    ax2.legend(loc='upper right')

    # 2. Equity Curve
    axs[1].plot(times, equity[:len(times)], label='Equity Curve', color='green')
    axs[1].set_ylabel('Equity ($)')
    axs[1].set_title(f"{name} - Equity Curve")
    axs[1].legend()
    axs[1].grid(True)

    # 3. Drawdown
    axs[2].plot(times, unrealized_dd[:len(times)], label='Unrealized Drawdown', color='red')
    axs[2].plot(times, realized_dd[:len(times)], label='Realized Drawdown', color='orange', linestyle='--', marker='o', markersize=3)
    axs[2].set_ylabel('Drawdown')
    axs[2].set_title(f"{name} - Drawdown")
    axs[2].legend()
    axs[2].grid(True)

    # 4. Rolling Sharpe
    axs[3].plot(times, rolling_sharpe[:len(times)], label='Rolling Sharpe (30d)', color='purple')
    axs[3].set_ylabel('Sharpe')
    axs[3].set_title(f"{name} - Rolling Sharpe Ratio")
    axs[3].legend()
    axs[3].grid(True)

    # 5. Trades (Buy/Sell markers)
    axs[4].plot(times, df['close'], color='blue', alpha=0.5)
    # Only keep indices that are within the bounds of df/times
    buys = [idx for idx in [t['entry_idx'] for t in results['trades']] if idx < len(df)]
    sells = [idx for idx in [t['exit_idx'] for t in results['trades']] if idx < len(df)]

    axs[4].scatter(times.iloc[buys], df['close'].iloc[buys], marker='^', color='green', label='Buy', zorder=5)
    axs[4].scatter(times.iloc[sells], df['close'].iloc[sells], marker='v', color='red', label='Sell', zorder=5)
    axs[4].set_ylabel('BTC Price')
    axs[4].set_title(f"{name} - Buy/Sell Points")
    axs[4].legend()
    axs[4].grid(True)

    # X-axis formatting
    axs[-1].xaxis.set_major_locator(mdates.AutoDateLocator())
    axs[-1].xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

    plt.tight_layout()
    plt.show()

# Example usage:
plot_strategy_results(bt_df, bh_results, name="Buy & Hold")
plot_strategy_results(bt_df, sma_results, name="SMA Crossover")

# %% [markdown]
# ---

# %% [markdown]
# # To do right now
#  - [ ] Make our backtest more efficient / faster

# %% [markdown]
# ---
# ---
